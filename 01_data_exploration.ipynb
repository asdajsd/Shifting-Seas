# %% [markdown]
# # 📊 01 - Data Exploration
# Initial exploration of the ocean climate dataset.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_csv('../data/realistic_ocean_climate_dataset.csv')
df.head()

# %%
# Summary statistics
df.describe(include='all')
